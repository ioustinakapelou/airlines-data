# %%
arff_file_path = r"C:\Users\ioust\Desktop\mining2\Airlines.arff"


with open(arff_file_path, 'r') as file:
    arff_content = file.read()


arff_content = arff_content.replace("'PA (1)'", '"PA (1)"')


with open(arff_file_path, 'w') as file:
    file.write(arff_content)

# %%
from scipy.io.arff import loadarff
import pandas as pd


file_path = r"C:\Users\ioust\Desktop\mining2\Airlines.arff"
data, meta = loadarff(file_path)


df = pd.DataFrame(data)


df = df.applymap(lambda x: x.decode('utf-8') if isinstance(x, bytes) else x)


print(df.head())
# Out:
#    DayofWeek  CRSDepTime UniqueCarrier FlightNum Origin Dest  ArrDelay
# 0        5.0       600.0            UA     899.0    ORD  IAD      -3.0
# 1        5.0       615.0            DL     357.0    IAD  ATL       5.0
# 2        5.0       615.0            UA     341.0    IAD  DEN       8.0
# 3        5.0       625.0            CO     581.0    IAD  DEN      44.0
# 4        5.0       630.0            UA     902.0    CLE  IAD     -10.0
# C:\Users\ioust\AppData\Local\Temp\ipykernel_11680\2742314297.py:12: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.decode('utf-8') if isinstance(x, bytes) else x)

# %%
df.shape
# Out:
# (100161, 7)

# %%
df.dtypes
# Out:
# DayofWeek        float64
# CRSDepTime       float64
# UniqueCarrier     object
# FlightNum         object
# Origin            object
# Dest              object
# ArrDelay         float64
# dtype: object

# %%
df.isnull()
# Out:
#         DayofWeek  CRSDepTime  UniqueCarrier  FlightNum  Origin   Dest  \
# 0           False       False          False      False   False  False
# 1           False       False          False      False   False  False
# 2           False       False          False      False   False  False
# 3           False       False          False      False   False  False
# 4           False       False          False      False   False  False
# ...           ...         ...            ...        ...     ...    ...
# 100156      False       False          False      False   False  False
# 100157      False       False          False      False   False  False
# 100158      False       False          False      False   False  False
# 100159      False       False          False      False   False  False
# 100160      False       False          False      False   False  False
#
#         ArrDelay
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
# ...

# %%
df.describe()
# Out:
#            DayofWeek     CRSDepTime       ArrDelay
# count  100161.000000  100161.000000  100161.000000
# mean        3.952626    1357.918262       4.638462
# std         1.985074     460.022924      23.397863
# min         1.000000       5.000000     -72.000000
# 25%         2.000000     925.000000      -7.000000
# 50%         4.000000    1335.000000       0.000000
# 75%         6.000000    1735.000000       9.000000
# max         7.000000    2359.000000     667.000000

# %%
df.groupby('UniqueCarrier').size()
# Out:
# UniqueCarrier
# AA         8620
# CO         9219
# DL         4793
# EA         1420
# NW         5521
# PA (1)      313
# TW         3056
# UA        63706
# US         3513
# dtype: int64

# %%
df.groupby('Origin').count()
# Out:
#         DayofWeek  CRSDepTime  UniqueCarrier  FlightNum   Dest  ArrDelay
# Origin
# ATL          2820        2820           2820       2820   2820      2820
# BDL          1795        1795           1795       1795   1795      1795
# BNA           294         294            294        294    294       294
# BOS          2210        2210           2210       2210   2210      2210
# BTV           326         326            326        326    326       326
# BUF           835         835            835        835    835       835
# BWI            43          43             43         43     43        43
# CAE           446         446            446        446    446       446
# CHS           534         534            534        534    534       534
# CLE          1458        1458           1458       1458   1458      1458
# DCA             3           3              3          3      3         3
# DEN          2911        2911           2911       2911   2911      2911
# ...

# %%
df.groupby('FlightNum').count()
# Out:
#            DayofWeek  CRSDepTime  UniqueCarrier  Origin  Dest  ArrDelay
# FlightNum
# 1000.0           414         414            414     414   414       414
# 1001.0           167         167            167     167   167       167
# 1002.0           293         293            293     293   293       293
# 1003.0             2           2              2       2     2         2
# 1007.0            58          58             58      58    58        58
# ...              ...         ...            ...     ...   ...       ...
# 990.0             50          50             50      50    50        50
# 993.0             59          59             59      59    59        59
# 995.0            186         186            186     186   186       186
# 996.0             48          48             48      48    48        48
# 998.0             18          18             18      18    18        18
#
# [624 rows x 6 columns]

# %%
df.groupby('Dest').count()
# Out:
#       DayofWeek  CRSDepTime  UniqueCarrier  FlightNum  Origin  ArrDelay
# Dest
# ATL        2847        2847           2847       2847    2847      2847
# BDL        1783        1783           1783       1783    1783      1783
# BNA         307         307            307        307     307       307
# BOS        2209        2209           2209       2209    2209      2209
# BTV         317         317            317        317     317       317
# BUF         820         820            820        820     820       820
# BWI          35          35             35         35      35        35
# CAE         442         442            442        442     442       442
# CHS         524         524            524        524     524       524
# CLE        1417        1417           1417       1417    1417      1417
# CRW         109         109            109        109     109       109
# DCA           4           4              4          4       4         4
# ...

# %%
df.groupby('DayofWeek').size()
# Out:
# DayofWeek
# 1.0    14509
# 2.0    14554
# 3.0    14686
# 4.0    14576
# 5.0    14780
# 6.0    13372
# 7.0    13684
# dtype: int64

# %%
import matplotlib.pyplot as plt
grouped_data = df.groupby('DayofWeek').size()

df.groupby('DayofWeek').size()
plt.figure(figsize=(8, 6))
grouped_data.plot(kind='bar', color='skyblue')
plt.title('Frequency of Flights by Day of Week')
plt.xlabel('Day of Week')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()


plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.hist(df['CRSDepTime'], bins=24, color='skyblue', edgecolor='black', alpha=0.7)

plt.title('Frequency of Flights by Time of Day')
plt.xlabel('Time  Departure Time in 24-hours')
plt.ylabel('Count')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.xticks(ticks=range(0, 2401, 200), rotation=45)  
plt.tight_layout()


plt.show()

# %%
grouped_data = df.groupby('UniqueCarrier').size()

df.groupby('UniqueCarrier').size()
plt.figure(figsize=(8, 6))
grouped_data.plot(kind='bar', color='skyblue')
plt.title('Frequency of Carrier')
plt.xlabel('Carrier')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()


plt.show()

# %%
grouped_data = df.groupby('Origin').size()

df.groupby('Origin').size()
plt.figure(figsize=(8, 6))
grouped_data.plot(kind='bar', color='skyblue')
plt.title('Origin airport distribution')
plt.xlabel('origin')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()


plt.show()

# %%
grouped_data = df.groupby('Dest').size()

df.groupby('Dest').size()
plt.figure(figsize=(8, 6))
grouped_data.plot(kind='bar', color='skyblue')
plt.title('Destination airport distribution')
plt.xlabel('dest')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()


plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['ArrDelay'], bins=10, color='skyblue', edgecolor='black', alpha=0.7)


plt.title('Frequency of Delays', fontsize=14)
plt.xlabel('Delay (minutes)', fontsize=12)
plt.ylabel('Count', fontsize=12)


max_delay = int(max(df['ArrDelay'])) 
x_ticks = range(-72, max_delay + 60, 60)  
plt.xticks(ticks=x_ticks, labels=x_ticks, rotation=45)


plt.grid(axis='y', linestyle='--', alpha=0.7)


plt.tight_layout()

plt.show()

# %%
df.groupby('UniqueCarrier')['ArrDelay'].mean()
# Out:
# UniqueCarrier
# AA         1.908237
# CO         4.919948
# DL         5.118715
# EA        11.728169
# NW         5.004890
# PA (1)    16.223642
# TW         5.179647
# UA         4.569664
# US         6.246798
# Name: ArrDelay, dtype: float64

# %%
average_delays = df.groupby('UniqueCarrier')['ArrDelay'].mean()

plt.figure(figsize=(8, 6))
plt.bar(average_delays.index, average_delays, color='skyblue', edgecolor='black')
plt.title('Average Delay Time by Airline')
plt.xlabel('Airline')
plt.ylabel('Average Delay (minutes)')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()

# %%
df.groupby('Origin')['ArrDelay'].mean()
# Out:
# Origin
# ATL     5.748936
# BDL     5.387744
# BNA    -4.295918
# BOS     9.550679
# BTV     1.064417
# BUF     1.237126
# BWI     1.441860
# CAE     4.309417
# CHS     1.717228
# CLE     1.936900
# DCA     6.666667
# DEN     6.368602
# DFW     0.218182
# DTW     2.674632
# EWR     4.149254
# FLL     2.493597
# GSO    -4.425532
# HOU    -4.283582
# HPN    12.171053
# IAD     5.190269
# IAH    -1.612989
# IND    -3.082005
# ISP     2.301370
# JAX    -3.750000
# JFK     2.676056
# LAX     0.553840
# LGA     2.892555
# MCO     3.822130
# MDT    11.000000
# MDW    -0.548387
# MEM     3.369878
# MHT    11.199105
# MIA     1.938776
# MSP     5.167702
# MSY     5.500000
# ORD    10.605521
# ORF     6.229755
# PBI     6.845930
# PHF     0.047887
# PHL     3.038314
# PHX    -2.659341
# PIT     6.401529
# PVD    12.334459
# PWM     8.491749
# RDU     1.369806
# RIC    13.000000
# ROC     1.531861
# RSW     0.400621
# SAV     1.870647
# SDF    -1.021605
# SEA     2.498328
# SFO     7.108089
# ...

# %%
average_delayso = df.groupby('Origin')['ArrDelay'].mean()

plt.figure(figsize=(8, 6))
plt.bar(average_delayso.index, average_delayso, color='skyblue', edgecolor='black')
plt.title('Average Delay Time per Origin Airport')
plt.xlabel('Origin')
plt.ylabel('Average Delay (minutes)')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()

# %%
df.groupby('Dest')['ArrDelay'].mean()
# Out:
# Dest
# ATL     3.265894
# BDL     7.168256
# BNA    -0.195440
# BOS     8.570847
# BTV     0.217666
# BUF     2.539024
# BWI    -6.000000
# CAE     0.692308
# CHS    11.830153
# CLE     8.035286
# CRW    -6.211009
# DCA     3.000000
# DEN     5.261564
# DFW     2.097717
# DTW     4.829739
# EWR     8.528418
# FLL    14.638554
# GSO    -6.012158
# HOU     8.954545
# HPN     2.328829
# IAD     4.083373
# IAH     4.073019
# IND     1.016092
# ISP    -2.119718
# JAX     1.990437
# JFK     9.690909
# LAX     0.719517
# LGA     5.377581
# MCO     9.545346
# MDT    21.000000
# MDW    11.873016
# MEM     4.674145
# MHT     0.347534
# MIA     7.196009
# MSP     8.340841
# MSY     5.692731
# ORD     5.786903
# ORF     2.712946
# PBI    11.072857
# PHF     1.416431
# PHL     6.934949
# PHX     2.186667
# PIT     6.639838
# PVD     1.922559
# PWM     1.114379
# RDU     7.352941
# RIC     2.000000
# ROC     3.553556
# RSW     5.433846
# SAV     5.617978
# SDF     4.451713
# SEA     3.325658
# ...

# %%
average_delaysd = df.groupby('Dest')['ArrDelay'].mean()

plt.figure(figsize=(8, 6))
plt.bar(average_delaysd.index, average_delaysd, color='skyblue', edgecolor='black')
plt.title('Average Delay Time per Destination Airport')
plt.xlabel('Dest')
plt.ylabel('Average Delay (minutes)')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()

# %%
df2 = df.copy()

df2['Delay'] = df2['ArrDelay'].apply(
    lambda x: 'Early' if x < 0 else ('On Time' if x == 0 else 'Late'))

# %%
columns_to_keep = [ 'Origin','Dest','Delay']

df2 = df2[columns_to_keep]

# %%
columns_to_keep = [ 'Delay','Origin']

dforigin = df2[columns_to_keep]

# %%
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules


dforigin['Delay'] = dforigin['Delay'].apply(lambda x: f"Delay={x}")
dforigin['Origin'] = dforigin['Origin'].apply(lambda x: f"Origin={x}")


transactions = dforigin.values.tolist()

te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)

df_transformed = pd.DataFrame(te_ary, columns=te.columns_)

frequent_itemsets = apriori(df_transformed, min_support=0.000001, use_colnames=True)

assoc_rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.7,num_itemsets=10)

rules_sorted = assoc_rules.sort_values(by='confidence', ascending=False)


rules_sorted.iloc[:, 0:7]
# Out:
# C:\Users\ioust\AppData\Local\Temp\ipykernel_11680\2650259979.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dforigin['Delay'] = dforigin['Delay'].apply(lambda x: f"Delay={x}")
# C:\Users\ioust\AppData\Local\Temp\ipykernel_11680\2650259979.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dforigin['Origin'] = dforigin['Origin'].apply(lambda x: f"Origin={x}")
#     antecedents    consequents  antecedent support  consequent support  \
# ...

# %%
columns_to_keep = [ 'Delay','Origin']

dforigin2 = df2[columns_to_keep]

# %%
dforigin2['Delay'] = dforigin2['Delay'].apply(lambda x: f"Delay={x}")
dforigin2['Origin'] = dforigin2['Origin'].apply(lambda x: f"Origin={x}")

transactions = dforigin2.values.tolist()

te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)


df_transformed = pd.DataFrame(te_ary, columns=te.columns_)


frequent_itemsets = apriori(df_transformed, min_support=0.000001, use_colnames=True)

assoc_rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.3,num_itemsets=10)

assoc_rules = assoc_rules[assoc_rules['antecedents'].apply(lambda x: any("Delay" in item for item in x))]

rules_sorted = assoc_rules.sort_values(by='confidence', ascending=False)


rules_sorted.iloc[:, 0:7]
# Out:
# C:\Users\ioust\AppData\Local\Temp\ipykernel_11680\2786726813.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dforigin2['Delay'] = dforigin2['Delay'].apply(lambda x: f"Delay={x}")
# C:\Users\ioust\AppData\Local\Temp\ipykernel_11680\2786726813.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dforigin2['Origin'] = dforigin2['Origin'].apply(lambda x: f"Origin={x}")
#          antecedents   consequents  antecedent support  consequent support  \
# ...

# %%
columns_to_keep = [ 'Delay','Dest']

dfdest = df2[columns_to_keep]

# %%
dfdest['Delay'] = dfdest['Delay'].apply(lambda x: f"Delay={x}")
dfdest['Dest'] = dfdest['Dest'].apply(lambda x: f"Dest={x}")


transactions = dfdest.values.tolist()

te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)

df_transformed = pd.DataFrame(te_ary, columns=te.columns_)

frequent_itemsets = apriori(df_transformed, min_support=0.000001, use_colnames=True)
assoc_rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.7,num_itemsets=10)


rules_sorted = assoc_rules.sort_values(by='confidence', ascending=False)


rules_sorted.iloc[:, 0:7]
# Out:
# C:\Users\ioust\AppData\Local\Temp\ipykernel_11680\454571726.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfdest['Delay'] = dfdest['Delay'].apply(lambda x: f"Delay={x}")
# C:\Users\ioust\AppData\Local\Temp\ipykernel_11680\454571726.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfdest['Dest'] = dfdest['Dest'].apply(lambda x: f"Dest={x}")
#   antecedents    consequents  antecedent support  consequent support  \
# ...

# %%
columns_to_keep = [ 'Delay','Dest']

dfdest2 = df2[columns_to_keep]

# %%
dfdest2['Delay'] = dfdest2['Delay'].apply(lambda x: f"Delay={x}")
dfdest2['Dest'] = dfdest2['Dest'].apply(lambda x: f"Dest={x}")


transactions = dfdest2.values.tolist()

te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)

df_transformed = pd.DataFrame(te_ary, columns=te.columns_)


frequent_itemsets = apriori(df_transformed, min_support=0.000001, use_colnames=True)


assoc_rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.3,num_itemsets=10)

assoc_rules = assoc_rules[assoc_rules['antecedents'].apply(lambda x: any("Delay" in item for item in x))]

rules_sorted = assoc_rules.sort_values(by='confidence', ascending=False)

rules_sorted.iloc[:, 0:7]
# Out:
# C:\Users\ioust\AppData\Local\Temp\ipykernel_11680\580636624.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfdest2['Delay'] = dfdest2['Delay'].apply(lambda x: f"Delay={x}")
# C:\Users\ioust\AppData\Local\Temp\ipykernel_11680\580636624.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfdest2['Dest'] = dfdest2['Dest'].apply(lambda x: f"Dest={x}")
#          antecedents consequents  antecedent support  consequent support  \
# ...

# %%
columns_to_keep = [ 'Origin','Dest','Delay']

dfall = df2[columns_to_keep]

# %%
dfall['Delay'] = dfall['Delay'].apply(lambda x: f"Delay={x}")
dfall['Dest'] = dfall['Dest'].apply(lambda x: f"Dest={x}")
dfall['Origin'] = dfall['Origin'].apply(lambda x: f"Origin={x}")


transactions = dfall.values.tolist()

te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)

df_transformed = pd.DataFrame(te_ary, columns=te.columns_)

frequent_itemsets = apriori(df_transformed, min_support=0.000001, use_colnames=True)

assoc_rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.7,num_itemsets=10)

filtered_rules = assoc_rules[
    assoc_rules['antecedents'].apply(
        lambda x: any(item.startswith("Delay") for item in x)
    )
]

rules_sorted = filtered_rules.sort_values(by=['confidence', 'support'], ascending=[False, False])

rules_sorted.iloc[:, 0:7]
# Out:
#                    antecedents   consequents  antecedent support  \
# 285   (Origin=ATL, Delay=Late)    (Dest=IAD)            0.016044
# 323   (Delay=Late, Origin=ORD)    (Dest=IAD)            0.015245
# 147    (Dest=DEN, Delay=Early)  (Origin=IAD)            0.015146
# 296   (Origin=DEN, Delay=Late)    (Dest=IAD)            0.014467
# 229    (Dest=LAX, Delay=Early)  (Origin=IAD)            0.014297
# ..                         ...           ...                 ...
# 406  (Delay=On Time, Dest=CRW)  (Origin=IAD)            0.000010
# 407  (Dest=DCA, Delay=On Time)  (Origin=IAD)            0.000010
# 414  (Delay=On Time, Dest=HOU)  (Origin=IAD)            0.000010
# 488  (Dest=PHX, Delay=On Time)  (Origin=IAD)            0.000010
# 501  (Dest=SRQ, Delay=On Time)  (Origin=IAD)            0.000010
#
#      consequent support   support  confidence      lift
# 285            0.498517  0.016044         1.0  2.005948
# 323            0.498517  0.015245         1.0  2.005948
# ...

# %%
dfpred = df.copy()

dfpred['Delay'] = dfpred['ArrDelay'].apply(
    lambda x: 'Early' if x < 0 else ('On Time' if x == 0 else 'Late'))

# %%
dfpred = dfpred.drop(columns=['ArrDelay'])

# %%
columns_to_encode = ['UniqueCarrier', 'Origin', 'Dest']


dfpred= pd.get_dummies(dfpred, columns=columns_to_encode,dtype=int)

# %%
column_to_move = 'Delay'
dfpred= dfpred[[col for col in dfpred if col != column_to_move] + [column_to_move]]

# %%
values = {'Early': 0, 'On Time': 1, 'Late': 2}
dfpred['target'] = dfpred['Delay'].map(values)

# %%
dfpred = dfpred.drop(columns=['Delay'])

# %%
dfpred['target'] = dfpred['target'].astype(int)

# %%
array = dfpred.values
X = array[:, 0:129] 
Y = array[:, 129]

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
kfold = KFold(n_splits=10,shuffle=True, random_state=7)
Y = pd.cut(Y, bins=3, labels=[0, 1, 2])
log_reg = LogisticRegression(multi_class='multinomial', solver='lbfgs', max_iter=100)


results = cross_val_score(log_reg, X, Y, cv=kfold, scoring='accuracy')
print("Mean Accuracy:", results.mean())
# Out:
# c:\Users\ioust\Desktop\mining2\min\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# c:\Users\ioust\Desktop\mining2\min\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier
results = cross_val_score(KNeighborsClassifier(), X, Y, cv=kfold)
print(results.mean())
# Out:
# 0.5989657029934096

# %%
from sklearn.naive_bayes import MultinomialNB

mnb= MultinomialNB()
results = cross_val_score(mnb, X, Y, cv=kfold)
print( results.mean())
# Out:
# 0.5105280747170704

# %%
from sklearn.tree import DecisionTreeClassifier
results = cross_val_score(DecisionTreeClassifier(), X, Y, cv=kfold)
print(results.mean())
# Out:
# 0.6153792546281545

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score


rf_model = RandomForestClassifier(random_state=7)  
results = cross_val_score(rf_model, X, Y, cv=kfold)  
print(results.mean())
# Out:
# 0.6170366367590432

# %%
from sklearn.preprocessing import MinMaxScaler
array = dfpred.values

X = array[:,0:129]
Y = array[:,129]
scaler = MinMaxScaler(feature_range=(0, 1))
rescaledX = scaler.fit_transform(X)

# %%
from sklearn.linear_model import LogisticRegression
Y = pd.cut(Y, bins=3, labels=[0, 1, 2])
log_reg = LogisticRegression(multi_class='multinomial', solver='lbfgs', max_iter=100)


results = cross_val_score(log_reg, rescaledX, Y, cv=kfold, scoring='accuracy')
print("Mean Accuracy:", results.mean())
# Out:
# c:\Users\ioust\Desktop\mining2\min\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# c:\Users\ioust\Desktop\mining2\min\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# c:\Users\ioust\Desktop\mining2\min\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier
results = cross_val_score(KNeighborsClassifier(), rescaledX, Y, cv=kfold)
print(results.mean())
# Out:
# 0.5957009366026635

# %%
from sklearn.naive_bayes import MultinomialNB

mnb= MultinomialNB()
results = cross_val_score(mnb, rescaledX, Y, cv=kfold)
print( results.mean())
# Out:
# 0.5518713923151728

# %%
from sklearn.tree import DecisionTreeClassifier
results = cross_val_score(DecisionTreeClassifier(), rescaledX, Y, cv=kfold)
print(results.mean())
# Out:
# 0.6154291717658256

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score


rf_model = RandomForestClassifier(random_state=7)  
results = cross_val_score(rf_model, rescaledX, Y, cv=kfold)  
print(results.mean())
# Out:
# 0.6168968604012156

# %%
from sklearn.decomposition import PCA
import numpy as np

pca = PCA(n_components=0.95) 
X_reduced = pca.fit_transform(X)


num_features = pca.n_components_

print(f"Optimal number of features to retain 95% variance: {num_features}")
# Out:
# Optimal number of features to retain 95% variance: 2

# %%
from sklearn.linear_model import LogisticRegression
Y = pd.cut(Y, bins=3, labels=[0, 1, 2])
log_reg = LogisticRegression(multi_class='multinomial', solver='lbfgs', max_iter=100)


results = cross_val_score(log_reg, X_reduced, Y, cv=kfold, scoring='accuracy')
print("Mean Accuracy:", results.mean())
# Out:
# c:\Users\ioust\Desktop\mining2\min\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# c:\Users\ioust\Desktop\mining2\min\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# c:\Users\ioust\Desktop\mining2\min\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier
results = cross_val_score(KNeighborsClassifier(), X_reduced, Y, cv=kfold)
print(results.mean())
# Out:
# 0.600163686389687

# %%
from sklearn.tree import DecisionTreeClassifier
results = cross_val_score(DecisionTreeClassifier(), X_reduced, Y, cv=kfold)
print(results.mean())
# Out:
# 0.618334508252903

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score


rf_model = RandomForestClassifier(random_state=7)  
results = cross_val_score(rf_model, X_reduced, Y, cv=kfold)  
print(results.mean())
# Out:
# 0.6185841268326273

# %%
dfpred = df.copy()

dfpred['Delay'] = dfpred['ArrDelay'].apply(
    lambda x: 'Early' if x < 0 else ('On Time' if x == 0 else 'Late'))
dfpred = dfpred.drop(columns=['ArrDelay'])
columns_to_encode = ['UniqueCarrier', 'Origin', 'Dest']


dfpred= pd.get_dummies(dfpred, columns=columns_to_encode,dtype=int)
column_to_move = 'Delay'
dfpred= dfpred[[col for col in dfpred if col != column_to_move] + [column_to_move]]

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV, train_test_split
array = dfpred.values
X = array[:,0:129]
Y = array[:,129]

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=7)
dt = DecisionTreeClassifier(random_state=7)


param_grid = {'max_depth': range(1, 10)}  

grid_search = GridSearchCV(estimator=dt, param_grid=param_grid, scoring='accuracy', cv=7)

grid_search.fit(X_train, y_train)

print("Best Parameters:", grid_search.best_params_)

best_dt = grid_search.best_estimator_
test_accuracy = best_dt.score(X_test, y_test)
print("Test Set Accuracy:", test_accuracy)
# Out:
# Best Parameters: {'max_depth': 9}
# Test Set Accuracy: 0.5592532197410895

# %%
from sklearn.metrics import accuracy_score, classification_report
from sklearn.tree import DecisionTreeClassifier  


X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.3, random_state=7)


model = DecisionTreeClassifier(random_state=7, max_depth=9, criterion='entropy')

model.fit(X_train, y_train)

y_pred = model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")

print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.56
# Classification Report:
#               precision    recall  f1-score   support
#
#        Early       0.55      0.59      0.57     14155
#         Late       0.57      0.58      0.57     14701
#      On Time       0.25      0.00      0.00      1193
#
#     accuracy                           0.56     30049
#    macro avg       0.46      0.39      0.38     30049
# weighted avg       0.55      0.56      0.55     30049

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
cm = confusion_matrix(y_test, y_pred, labels=["Early", "Late", "On Time"])


disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["Early", "Late", "On Time"])
fig, ax = plt.subplots(figsize=(8, 6)) 
disp.plot(cmap='Greens', ax=ax)

plt.title('Confusion Matrix')  
plt.show()

# %%
dfclass = df.copy()

dfclass['Delay'] = dfclass['ArrDelay'].apply(
    lambda x: 'Early' if x < 0 else ('On Time' if x == 0 else 'Late'))

# %%
dfclass = dfclass.drop(columns=['ArrDelay'])

# %%
columns_to_encode = ['UniqueCarrier', 'Origin', 'Dest']


dfencod = pd.get_dummies(dfclass, columns=columns_to_encode,dtype=int)

# %%
column_to_move = 'Delay'
dfencod = dfencod[[col for col in dfencod if col != column_to_move] + [column_to_move]]

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV, train_test_split
array = dfencod.values
X = array[:,0:129]
Y = array[:,129]

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=7)
dt = DecisionTreeClassifier(random_state=7)

param_grid = {'max_depth': range(1, 5)}  

grid_search = GridSearchCV(estimator=dt, param_grid=param_grid, scoring='accuracy', cv=7)

grid_search.fit(X_train, y_train)

print("Best Parameters:", grid_search.best_params_)

best_dt = grid_search.best_estimator_
test_accuracy = best_dt.score(X_test, y_test)
print("Test Set Accuracy:", test_accuracy)
# Out:
# Best Parameters: {'max_depth': 4}
# Test Set Accuracy: 0.5443442377450165

# %%
import numpy as np

array = dfencod.values
X = array[:,0:129]
Y = array[:,129]
feature_names = dfencod.columns.tolist()[:129]
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=7)
tree = DecisionTreeClassifier(criterion='entropy', max_depth=4, random_state=7)
tree.fit(X_train, y_train)
importances = tree.feature_importances_
important_features = np.argsort(importances)[::-1]  

N = 5
top_features = [feature_names[i] for i in important_features[:N]]

from sklearn.tree import  export_text
rules = export_text(tree, feature_names=feature_names)

print("\nTop  Most Prominent Rules Including Leaf Nodes")
for line in rules.splitlines():
    if any(feature in line for feature in top_features) or "class:" in line:
        print(line)
# Out:
# Top  Most Prominent Rules Including Leaf Nodes
# |--- CRSDepTime <= 1442.00
# |   |--- UniqueCarrier_US <= 0.50
# |   |   |--- UniqueCarrier_NW <= 0.50
# |   |   |   |--- DayofWeek <= 5.50
# |   |   |   |   |--- class: Early
# |   |   |   |--- DayofWeek >  5.50
# |   |   |   |   |--- class: Early
# |   |   |--- UniqueCarrier_NW >  0.50
# |   |   |   |   |--- class: Late
# |   |   |   |   |--- class: Late
# |   |--- UniqueCarrier_US >  0.50
# |   |   |--- Origin_PHF <= 0.50
# |   |   |   |   |--- class: Late
# |   |   |   |   |--- class: Early
# |   |   |--- Origin_PHF >  0.50
# |   |   |   |--- CRSDepTime <= 1130.00
# |   |   |   |   |--- class: Late
# |   |   |   |--- CRSDepTime >  1130.00
# |   |   |   |   |--- class: Early
# |--- CRSDepTime >  1442.00
# |   |--- CRSDepTime <= 2127.50
# |   |   |   |--- DayofWeek <= 5.50
# |   |   |   |   |--- class: Late
# |   |   |   |--- DayofWeek >  5.50
# |   |   |   |   |--- class: Late
# |   |   |   |   |--- class: Late
# ...

# %%
from sklearn.tree import plot_tree 

plt.figure(figsize=(33, 15))  
plot_tree(tree, 
          feature_names=feature_names,  
          class_names=np.unique(Y),    
          filled=True,                  
          rounded=True,                 
          fontsize=10)                 


plt.show()
